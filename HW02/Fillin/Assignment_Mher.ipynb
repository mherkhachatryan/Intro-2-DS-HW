# %% [markdown]
# ### To complete this assignment, recreate the plots and outputs of functions exactly.

# %% [markdown]
# ### Notice that some lines are missing code, but have the output still visible. In the line above recreate the function to generate the output below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv("data.csv")
df.head()
# Out:
#    BPrev  BStreak  B_Age  B_Height                          B_HomeTown  B_ID  \
# 0      1        1   23.0     182.0                        Trento Italy  2783
# 1      0        0   32.0     175.0  Careiro da Várzea, Amazonas Brazil  2208
# 2      2        0   38.0     172.0                      Kanagawa Japan   721
# 3      0        0   23.0     170.0                      Tijuana Mexico  2825
# 4      3        1   30.0     167.0                     Spokane, WA USA  2260
#
#           B_Location                 B_Name  B_Weight  \
# 0  Mezzocorona Italy         Marvin Vettori        84
# 1   Pharr, Texas USA  Carlos Diego Ferreira        70
# 2        Tokyo Japan          Takanori Gomi        70
# 3     Tijuana Mexico         Brandon Moreno        56
# 4    Spokane, WA USA     Elizabeth Phillips        61
#
#    B__Round1_Grappling_Reversals_Landed  ...  R__Round5_TIP_Ground Time  \
# 0                                   0.0  ...                        NaN
# ...

# %%
# Here is the first one. Re

# %%
df.describe()
# Out:
#              BPrev      BStreak        B_Age     B_Height         B_ID  \
# count  1477.000000  1477.000000  1474.000000  1476.000000  1477.000000
# mean      1.735274     0.654705    30.954545   177.451220  1964.633040
# std       1.895561     1.057269     4.020311     8.561541   666.949141
# min       0.000000     0.000000    20.000000   152.000000   129.000000
# 25%       0.000000     0.000000    28.000000   172.000000  1755.000000
# 50%       1.000000     0.000000    31.000000   177.000000  2156.000000
# 75%       3.000000     1.000000    34.000000   182.000000  2337.000000
# max      11.000000     7.000000    46.000000   213.000000  2882.000000
#
#           B_Weight  B__Round1_Grappling_Reversals_Landed  \
# count  1477.000000                            978.000000
# mean     73.804333                              0.036810
# std      14.980531                              0.193748
# min      52.000000                              0.000000
# ...

# %%
df['B_Age'] = df['B_Age'].fillna(np.mean(df['B_Age']))
df['B_Height'] = df['B_Height'].fillna(np.mean(df['B_Height']))
df['R_Age'] = df['R_Age'].fillna(np.mean(df['R_Age']))
df['R_Height'] = df['R_Height'].fillna(np.mean(df['R_Height']))

# %%
fig, ax = plt.subplots(1, 2, figsize=(9, 3))
sns.distplot(df['B_Age'], ax=ax[0])
sns.distplot(df['R_Age'], ax=ax[1])
# Out:
# <AxesSubplot:xlabel='R_Age', ylabel='Density'>

# %%
# Bonus
# Out:
# B_Age
# 30.0    164
# 33.0    138
# 29.0    134
# 32.0    128
# 27.0    120
# 31.0    112
# 28.0    106
# 34.0    106
# 26.0     72
# 35.0     67
# Name: winner, dtype: int64

# %%
above35 =['above35' if i >= 35 else 'below35' for i in df.B_Age]
df_B = pd.DataFrame({'B_Age':above35})
df_R = pd.DataFrame({'R_Age':above35})

# %%
df_B_dataframe = pd.DataFrame(df_B.value_counts(), columns=["value"])
df_R_dataframe = pd.DataFrame(df_R.value_counts(), columns=["value"])
col_names = [i for item in df_B_dataframe.index for i  in item]

# %%
_, ax = plt.subplots(1, 2, figsize=(9, 3))
sns.countplot(data = df_B, x ="B_Age", ax=ax[0])
sns.countplot(data = df_R, x ="R_Age", ax=ax[1])
ax[1].set_title("Age of Red fighter", c="red")
# Out:
# Text(0.5, 1.0, 'Age of Red fighters')

# %%
df_B
# Out:
#         B_Age
# 0     below35
# 1     below35
# 2     above35
# 3     below35
# 4     below35
# ...       ...
# 1472  below35
# 1473  below35
# 1474  above35
# 1475  below35
# 1476  below35
#
# [1477 rows x 1 columns]

# %%
sns.kdeplot(data=df, x="B_Height", shade=True)
# Out:
# <AxesSubplot:xlabel='B_Height', ylabel='Density'>

# %%
# comment from a student, it's not understandable what data used for plotting below plot!
# Out:
# <AxesSubplot:xlabel='B_Height', ylabel='Density'>

# %%
df_dec = df[df.winby=="DEC"]
df_ko = df[df.winby=="KO/TKO"]
df_sub = df[df.winby=="SUB"]

# %%
_, ax = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
sns.distplot(df_dec["R_Age"], ax=ax[0], kde=False).set_title = "winby = DEC"
sns.distplot(df_sub["R_Age"], ax=ax[1], kde=False).set_title = "winby = SUB"
sns.distplot(df_ko["R_Age"], ax=ax[2], kde=False).set_title = "winby = KO/TKO"

# %%
red = df[df.winner=="red"]
blue = df[df.winner=="blue"]
no_contest = df[df.winner=="no contest"]
draw = df[df.winner=="draw"]

# %%
# Bonus
_, ax = plt.subplots(2, 2, figsize=(12, 9), sharey=True, sharex=True)
sns.regplot(data=red, x="B__Round1_Strikes_Body Significant Strikes_Attempts", y="B__Round1_Strikes_Body Significant Strikes_Landed", ax=ax[0, 0]).set_title("winner = red")
sns.regplot(data=blue, x="B__Round1_Strikes_Body Significant Strikes_Attempts", y="B__Round1_Strikes_Body Significant Strikes_Landed", ax=ax[0, 1], color="orange").set_title("winner = blue")
sns.regplot(data=no_contest, x="B__Round1_Strikes_Body Significant Strikes_Attempts", y="B__Round1_Strikes_Body Significant Strikes_Landed", ax=ax[1, 0], color="green").set_title("winner = no contest")
sns.regplot(data=draw, x="B__Round1_Strikes_Body Significant Strikes_Attempts", y="B__Round1_Strikes_Body Significant Strikes_Landed", ax=ax[1, 1], color="red").set_title("winner = draw")
# Out:
# Text(0.5, 1.0, 'winner = draw')
